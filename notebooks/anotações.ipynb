# %% [markdown]
# <a href="https://colab.research.google.com/github/kowarski/fundamentos/blob/main/notebooks/anota%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introdução ao Pensamento Computacional

# %% [markdown]
# ## FERRAMENTAS/SERVIÇOS OTIMIZADOS
# - Google Colab (notebook com código)
# - GitHub (versionamento)
#
# ## PILARES
# - Decomposição
# - Abstração
# - Identificação de padrões
# - Lógica

# %% [markdown]
# ## Noções Gerais
#
# - Exemplos a partir de coleta de dados
#   - Site MRE - Notas de Imprensa
#     - [x] Link do site: https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa
#     - [x] Entender a estrutura da fonte de informação
#     - [ ] Realizar a coleta
#     - [ ] Inserir os dados em um banco de dados
#     - [ ] Utilizar as informações (análise de dados)
#
#
# ### Padrão da paginação das notas de imprensa:
# - https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=0
# - https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=30

# %%
1 # programs/bibliotecas utilizados no script/código
2 import httpx
3 from bs4 import BeautifulSoup
